# %%
from google.colab import drive
mount_path = '/content/gdrive/'
drive.mount(mount_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wGrZZt4VorwDHyAZbw9xjbPcwIgHeiN7JIMt5oNJY8Fq0VY1KHKH2M
# Mounted at /content/gdrive/

# %%
# Set and test path to competition data files
from termcolor import colored
competition_path = 'My Drive/Final Project ITC/MAFAT Challenge/Our notebooks/Michael/humans'
try:
  if competition_path == 'INSERT HERE':
    print('Please enter path to competition data files:')
    competition_path = input()
  file_path = '1_1.mat'
  with open(f'{mount_path}/{competition_path}/{file_path}') as f:
    print(f)
  print(colored('Everything is setup correctly', color='green'))
except:
  print(colored('Please mount drive and set competition_path correctly',
                color='red'))
# Out:
# <_io.TextIOWrapper name='/content/gdrive//My Drive/Final Project ITC/MAFAT Challenge/Our notebooks/Michael/humans/1_1.mat' mode='r' encoding='UTF-8'>
# Everything is setup correctly

# %%
import scipy.io
import os
import numpy as np
mat = scipy.io.loadmat('/content/gdrive/My Drive/Final Project ITC/MAFAT Challenge/Our notebooks/Michael/humans/1_12.mat')

# %%
mat['x'].reshape((128, -1)).shape
# Out:
# (128, 900)
